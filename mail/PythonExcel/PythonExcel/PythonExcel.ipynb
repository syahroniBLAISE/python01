# %% [markdown]
# ### Reading & Writing Excel Files with Python
#
# #### Documentation:
# https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html

# %% [markdown]
# #### Notebook by Bryan Cafferky, Copyright 2022
#
# For demonstration only. Not intended for production.

# %% [markdown]
# #### Code Example 01 - Read an Excel file...

# %%
import pandas as pd

pd.read_excel('DimGeography.xlsx')
# Out:
#      GeographyKey           City StateProvinceCode StateProvinceName  \
# 0               1     Alexandria               NSW   New South Wales
# 1               2  Coffs Harbour               NSW   New South Wales
# 2               3   Darlinghurst               NSW   New South Wales
# 3               4       Goulburn               NSW   New South Wales
# 4               5      Lane Cove               NSW   New South Wales
# ..            ...            ...               ...               ...
# 650           651        Mosinee                WI         Wisconsin
# 651           652         Racine                WI         Wisconsin
# 652           653         Casper                WY           Wyoming
# 653           654       Cheyenne                WY           Wyoming
# 654           655   Rock Springs                WY           Wyoming
#
#     CountryRegionCode EnglishCountryRegionName SpanishCountryRegionName  \
# 0                  AU                Australia                Australia
# 1                  AU                Australia                Australia
# 2                  AU                Australia                Australia
# 3                  AU                Australia                Australia
# 4                  AU                Australia                Australia
# ..                ...                      ...                      ...
# 650                US            United States           Estados Unidos
# 651                US            United States           Estados Unidos
# 652                US            United States           Estados Unidos
# 653                US            United States           Estados Unidos
# 654                US            United States           Estados Unidos
#
#     FrenchCountryRegionName PostalCode  SalesTerritoryKey IpAddressLocator
# 0                 Australie       2015                  9     198.51.100.2
# 1                 Australie       2450                  9     198.51.100.3
# 2                 Australie       2010                  9     198.51.100.4
# 3                 Australie       2580                  9     198.51.100.5
# 4                 Australie       1597                  9     198.51.100.6
# ..                      ...        ...                ...              ...
# 650              États-Unis      54455                  3    203.0.113.144
# 651              États-Unis      53182                  3    203.0.113.145
# 652              États-Unis      82601                  1    203.0.113.146
# 653              États-Unis      82001                  1    203.0.113.147
# 654              États-Unis      82901                  1    203.0.113.148
#
# [655 rows x 11 columns]

# %% [markdown]
# #### Code Example 02 - Read an Excel file into a pandas dataframe...

# %%
df_geo = pd.read_excel('DimGeography.xlsx', index_col=0)  
df_geo.head(2)
# Out:
#                        City StateProvinceCode StateProvinceName  \
# GeographyKey
# 1                Alexandria               NSW   New South Wales
# 2             Coffs Harbour               NSW   New South Wales
#
#              CountryRegionCode EnglishCountryRegionName  \
# GeographyKey
# 1                           AU                Australia
# 2                           AU                Australia
#
#              SpanishCountryRegionName FrenchCountryRegionName PostalCode  \
# GeographyKey
# 1                           Australia               Australie       2015
# 2                           Australia               Australie       2450
#
#               SalesTerritoryKey IpAddressLocator
# GeographyKey
# 1                             9     198.51.100.2
# 2                             9     198.51.100.3

# %% [markdown]
# #### Code Example 03 - Read a sheet within an Excel file into a dataframe...

# %%
df_sales = pd.read_excel('DimGeography.xlsx', sheet_name='salessheet', index_col=1)  
df_sales
# Out:
#             StoreID State  Year    Sales
# City
# Providence        1    RI  2015  1200000
# Boston            2    MA  2015  4000000
# Bangor            3    ME  2015  2300000
# Portsmouth        4    NH  2015  1200000
# New York          5    NY  2015   589000
# Nashville         6    TN  2015  1350000
# Harttford         7    CT  2015  3240000

# %% [markdown]
# #### Code Example 04 - Read a sheet within an Excel file into a dataframe, renaming columns.

# %%
df_sales2 = pd.read_excel('DimGeography.xlsx', sheet_name='salessheet', index_col=None, names=['A','B','C','D', 'E'])   
df_sales2
# Out:
#    A           B   C     D        E
# 0  1  Providence  RI  2015  1200000
# 1  2      Boston  MA  2015  4000000
# 2  3      Bangor  ME  2015  2300000
# 3  4  Portsmouth  NH  2015  1200000
# 4  5    New York  NY  2015   589000
# 5  6   Nashville  TN  2015  1350000
# 6  7   Harttford  CT  2015  3240000

# %% [markdown]
# #### Code Example 05 - Save dataframe to an Excel file.

# %% [markdown]
# #### Save data back to Excel...
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_excel.html

# %%
df_sales.to_excel('mysales.xlsx')

# %%
ls *.xlsx
# Out:
#  Volume in drive D is DATADRIVE0
#  Volume Serial Number is E6D7-EDE3
#
#  Directory of D:\DocumentsD\Presentations\PythonDataSources\PythonExcel
#
# 06/05/2022  10:11 AM            52,707 DimGeography.xlsx
# 06/05/2022  06:15 PM             5,716 mysales.xlsx
#                2 File(s)         58,423 bytes
#                0 Dir(s)  420,416,573,440 bytes free

# %% [markdown]
# #### Code Example 06 - Save dataframe to a sheet within an Excel file.

# %%
df_sales.to_excel('mysales.xlsx',sheet_name='secondsheet',index=False)

# %%
ls *.xlsx
# Out:
#  Volume in drive D is DATADRIVE0
#  Volume Serial Number is E6D7-EDE3
#
#  Directory of D:\DocumentsD\Presentations\PythonDataSources\PythonExcel
#
# 06/05/2022  10:11 AM            52,707 DimGeography.xlsx
# 06/05/2022  06:15 PM             5,622 mysales.xlsx
#                2 File(s)         58,329 bytes
#                0 Dir(s)  420,385,415,168 bytes free

# %% [markdown]
# #### Save data as CSV...
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html

# %% [markdown]
# #### Code Example 07 - Save dataframe to a CSV file.

# %%
df_sales.to_csv("mysles.csv", index=False)

# %%
ls *.csv
# Out:
#  Volume in drive D is DATADRIVE0
#  Volume Serial Number is E6D7-EDE3
#
#  Directory of D:\DocumentsD\Presentations\PythonDataSources\PythonExcel
#
# 06/05/2022  06:17 PM               158 mysles.csv
#                1 File(s)            158 bytes
#                0 Dir(s)  420,323,516,416 bytes free
